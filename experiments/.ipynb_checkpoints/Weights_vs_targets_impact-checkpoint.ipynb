# %%
from load_modules import *

# %%
file_location = "../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/"


filenames = glob.glob(file_location+'/[!Wave|metadata]*.txt')

data = load_files([filenames], True)
# Out:
# start loading data, number of files 51
# opening file 1 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#12.txt
# loaded  file 1 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#12.txt
# opening file 2 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#34.txt
# loaded  file 2 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#34.txt
# opening file 3 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#45.txt
# loaded  file 3 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#45.txt
# opening file 4 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#43.txt
# loaded  file 4 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#43.txt
# opening file 5 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150x25_60s_#13.txt
# loaded  file 5 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150x25_60s_#13.txt
# opening file 6 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#27.txt
# loaded  file 6 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#27.txt
# opening file 7 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#39.txt
# loaded  file 7 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#39.txt
# opening file 8 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#2.txt
# loaded  file 8 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#2.txt
# opening file 9 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#19.txt
# loaded  file 9 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#19.txt
# opening file 10 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#01.txt
# loaded  file 10 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#01.txt
# opening file 11 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#03.txt
# loaded  file 11 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#03.txt
# opening file 12 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#25.txt
# loaded  file 12 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#25.txt
# opening file 13 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#36.txt
# loaded  file 13 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#36.txt
# opening file 14 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150x25_60s_#9.txt
# loaded  file 14 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150x25_60s_#9.txt
# opening file 15 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#8.txt
# loaded  file 15 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#8.txt
# opening file 16 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#20.txt
# loaded  file 16 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#20.txt
# opening file 17 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#47.txt
# loaded  file 17 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#47.txt
# opening file 18 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#15.txt
# loaded  file 18 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#15.txt
# opening file 19 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#30.txt
# loaded  file 19 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#30.txt
# opening file 20 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#21.txt
# loaded  file 20 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#21.txt
# opening file 21 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#32.txt
# loaded  file 21 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#32.txt
# opening file 22 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#14.txt
# loaded  file 22 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#14.txt
# opening file 23 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#6.txt
# loaded  file 23 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#6.txt
# opening file 24 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#37.txt
# loaded  file 24 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#37.txt
# opening file 25 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#22.txt
# loaded  file 25 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#22.txt
# opening file 26 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#24.txt
# loaded  file 26 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#24.txt
# opening file 27 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#28.txt
# loaded  file 27 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#28.txt
# opening file 28 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#40.txt
# loaded  file 28 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#40.txt
# opening file 29 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#38.txt
# loaded  file 29 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#38.txt
# opening file 30 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#18.txt
# loaded  file 30 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#18.txt
# opening file 31 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#29.txt
# loaded  file 31 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#29.txt
# opening file 32 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#33.txt
# loaded  file 32 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#33.txt
# opening file 33 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#51.txt
# loaded  file 33 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#51.txt
# opening file 34 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#31.txt
# loaded  file 34 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#31.txt
# opening file 35 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#11.txt
# loaded  file 35 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#11.txt
# opening file 36 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#17.txt
# loaded  file 36 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#17.txt
# opening file 37 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150x25_60s_#7.txt
# loaded  file 37 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150x25_60s_#7.txt
# opening file 38 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#50.txt
# loaded  file 38 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#50.txt
# opening file 39 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#44.txt
# loaded  file 39 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#44.txt
# opening file 40 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150x25_60s_#10.txt
# loaded  file 40 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150x25_60s_#10.txt
# opening file 41 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#23.txt
# loaded  file 41 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#23.txt
# opening file 42 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#48.txt
# loaded  file 42 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#48.txt
# opening file 43 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#42.txt
# loaded  file 43 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#42.txt
# opening file 44 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#26.txt
# loaded  file 44 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Muscle_map_150z25_60s_#26.txt
# opening file 45 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#16.txt
# loaded  file 45 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#16.txt
# opening file 46 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#05.txt
# loaded  file 46 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#05.txt
# opening file 47 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#49.txt
# loaded  file 47 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#49.txt
# opening file 48 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#46.txt
# loaded  file 48 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#46.txt
# opening file 49 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#41.txt
# loaded  file 49 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#41.txt
# opening file 50 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#4.txt
# loaded  file 50 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Liver_map_150z25_60s_#4.txt
# opening file 51 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#35.txt
# loaded  file 51 of 51: ../../data/Raman_Mouse/preprocessed 2023-01-20 15-10-08.461978/Kidney_map_150z25_60s_#35.txt

# %%
img, wavenumbers = data[0][0], data[1][0]

# %%
LS = LSQ.photo_approximation(wavenumbers, order=7, size=img.shape[-1], FWHM=None)
LS2 = LSQ.photo_approximation(wavenumbers, order=7, size=img.shape[-1], FWHM=None, log=False)

raw = img[3,15]
photo = LS(img[3,15])
w = np.ones(len(raw))
w[photo > raw] += 1
w /= np.mean(w)
new_raw = copy.copy(raw)
new_raw[photo > raw] *= 0.975

update = LS(new_raw, w)

# %%
plt.rcParams['figure.figsize'] = (10, 3)
plt.rcParams['figure.dpi'] = 250
plt.rcParams['lines.linewidth'] = 1

# plt.plot(wavenumbers, new_raw, label="raw")
L,R = 0,1200
plt.plot(wavenumbers[L:R], raw[L:R], label="raw")
plt.plot(wavenumbers[L:R], photo[L:R], label=r"LS:$X\beta$")
# plt.plot(wavenumbers[L:R], update[0][L:R], label=r"WLST:$X\beta$")
plt.xlim(wavenumbers[L], wavenumbers[R])
plt.legend()
plt.xlabel(r"wavenumbers ($cm^{-1}$)")
plt.ylabel("intensity (-)")
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10, 3)
plt.rcParams['figure.dpi'] = 250
plt.rcParams['lines.linewidth'] = 1

# plt.plot(wavenumbers, new_raw, label="raw")
L,R = 0,1200
plt.plot(wavenumbers[L:R], np.log(raw[L:R]), label="raw")
plt.plot(wavenumbers[L:R], np.log(photo[L:R]), label=r"LS:$X\beta$")
# plt.plot(wavenumbers[L:R], update[0][L:R], label=r"WLST:$X\beta$")
plt.xlim(wavenumbers[L], wavenumbers[R])
plt.legend()
plt.xlabel(r"wavenumbers ($cm^{-1}$)")
plt.ylabel("intensity (-)")
plt.show()

# %%
from load_modules import *
import copy
from sklearn.decomposition import PCA
# Out:
# <style>.container { width:98% !important; }</style>

# %%
# file_location = "../../data/Raman_Mouse/noise_removed_used_for_tests/"
# filenames =  [f for f in glob.glob(file_location + "/*.txt") if "metadata" not in f.lower()]
# filenames = sorted(filenames)
# data = load_files([filenames], True)

file_location = "../../data/Raman_Mouse/real_photo_Our/"
filenames =  [f for f in glob.glob(file_location + "/*.txt") if "metadata" not in f.lower()]
filenames = sorted(filenames)
photo_Our = load_files([filenames], True)

file_location = "../../data/Raman_Mouse/real_photo_NN/"
filenames =  [f for f in glob.glob(file_location + "/*.txt") if "metadata" not in f.lower()]
filenames = sorted(filenames)
photo_NN = load_files([filenames], True)
# Out:
# start loading data, number of files 51
# opening file 1 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#35_photoluminescence.txt
# loaded  file 1 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#35_photoluminescence.txt
# opening file 2 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#36_photoluminescence.txt
# loaded  file 2 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#36_photoluminescence.txt
# opening file 3 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#37_photoluminescence.txt
# loaded  file 3 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#37_photoluminescence.txt
# opening file 4 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#38_photoluminescence.txt
# loaded  file 4 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#38_photoluminescence.txt
# opening file 5 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#39_photoluminescence.txt
# loaded  file 5 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#39_photoluminescence.txt
# opening file 6 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#40_photoluminescence.txt
# loaded  file 6 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#40_photoluminescence.txt
# opening file 7 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#41_photoluminescence.txt
# loaded  file 7 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#41_photoluminescence.txt
# opening file 8 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#42_photoluminescence.txt
# loaded  file 8 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#42_photoluminescence.txt
# opening file 9 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#43_photoluminescence.txt
# loaded  file 9 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#43_photoluminescence.txt
# opening file 10 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#44_photoluminescence.txt
# loaded  file 10 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#44_photoluminescence.txt
# opening file 11 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#45_photoluminescence.txt
# loaded  file 11 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#45_photoluminescence.txt
# opening file 12 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#46_photoluminescence.txt
# loaded  file 12 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#46_photoluminescence.txt
# opening file 13 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#47_photoluminescence.txt
# loaded  file 13 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#47_photoluminescence.txt
# opening file 14 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#48_photoluminescence.txt
# loaded  file 14 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#48_photoluminescence.txt
# opening file 15 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#49_photoluminescence.txt
# loaded  file 15 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#49_photoluminescence.txt
# opening file 16 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#50_photoluminescence.txt
# loaded  file 16 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#50_photoluminescence.txt
# opening file 17 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#51_photoluminescence.txt
# loaded  file 17 of 51: ../../data/Raman_Mouse/real_photo_Our/Kidney_map_150z25_60s_#51_photoluminescence.txt
# opening file 18 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150x25_60s_#10_photoluminescence.txt
# loaded  file 18 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150x25_60s_#10_photoluminescence.txt
# opening file 19 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150x25_60s_#13_photoluminescence.txt
# loaded  file 19 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150x25_60s_#13_photoluminescence.txt
# opening file 20 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150x25_60s_#7_photoluminescence.txt
# loaded  file 20 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150x25_60s_#7_photoluminescence.txt
# opening file 21 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150x25_60s_#9_photoluminescence.txt
# loaded  file 21 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150x25_60s_#9_photoluminescence.txt
# opening file 22 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#01_photoluminescence.txt
# loaded  file 22 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#01_photoluminescence.txt
# opening file 23 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#03_photoluminescence.txt
# loaded  file 23 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#03_photoluminescence.txt
# opening file 24 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#05_photoluminescence.txt
# loaded  file 24 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#05_photoluminescence.txt
# opening file 25 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#11_photoluminescence.txt
# loaded  file 25 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#11_photoluminescence.txt
# opening file 26 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#12_photoluminescence.txt
# loaded  file 26 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#12_photoluminescence.txt
# opening file 27 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#14_photoluminescence.txt
# loaded  file 27 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#14_photoluminescence.txt
# opening file 28 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#15_photoluminescence.txt
# loaded  file 28 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#15_photoluminescence.txt
# opening file 29 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#16_photoluminescence.txt
# loaded  file 29 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#16_photoluminescence.txt
# opening file 30 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#17_photoluminescence.txt
# loaded  file 30 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#17_photoluminescence.txt
# opening file 31 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#2_photoluminescence.txt
# loaded  file 31 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#2_photoluminescence.txt
# opening file 32 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#4_photoluminescence.txt
# loaded  file 32 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#4_photoluminescence.txt
# opening file 33 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#6_photoluminescence.txt
# loaded  file 33 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#6_photoluminescence.txt
# opening file 34 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#8_photoluminescence.txt
# loaded  file 34 of 51: ../../data/Raman_Mouse/real_photo_Our/Liver_map_150z25_60s_#8_photoluminescence.txt
# opening file 35 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#18_photoluminescence.txt
# loaded  file 35 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#18_photoluminescence.txt
# opening file 36 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#19_photoluminescence.txt
# loaded  file 36 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#19_photoluminescence.txt
# opening file 37 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#20_photoluminescence.txt
# loaded  file 37 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#20_photoluminescence.txt
# opening file 38 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#21_photoluminescence.txt
# loaded  file 38 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#21_photoluminescence.txt
# opening file 39 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#22_photoluminescence.txt
# loaded  file 39 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#22_photoluminescence.txt
# opening file 40 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#23_photoluminescence.txt
# loaded  file 40 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#23_photoluminescence.txt
# opening file 41 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#24_photoluminescence.txt
# loaded  file 41 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#24_photoluminescence.txt
# opening file 42 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#25_photoluminescence.txt
# loaded  file 42 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#25_photoluminescence.txt
# opening file 43 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#26_photoluminescence.txt
# loaded  file 43 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#26_photoluminescence.txt
# opening file 44 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#27_photoluminescence.txt
# loaded  file 44 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#27_photoluminescence.txt
# opening file 45 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#28_photoluminescence.txt
# loaded  file 45 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#28_photoluminescence.txt
# opening file 46 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#29_photoluminescence.txt
# loaded  file 46 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#29_photoluminescence.txt
# opening file 47 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#30_photoluminescence.txt
# loaded  file 47 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#30_photoluminescence.txt
# opening file 48 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#31_photoluminescence.txt
# loaded  file 48 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#31_photoluminescence.txt
# opening file 49 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#32_photoluminescence.txt
# loaded  file 49 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#32_photoluminescence.txt
# opening file 50 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#33_photoluminescence.txt
# loaded  file 50 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#33_photoluminescence.txt
# opening file 51 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#34_photoluminescence.txt
# loaded  file 51 of 51: ../../data/Raman_Mouse/real_photo_Our/Muscle_map_150z25_60s_#34_photoluminescence.txt
# start loading data, number of files 51
# opening file 1 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#35_photoluminescence.txt
# loaded  file 1 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#35_photoluminescence.txt
# opening file 2 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#36_photoluminescence.txt
# loaded  file 2 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#36_photoluminescence.txt
# opening file 3 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#37_photoluminescence.txt
# loaded  file 3 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#37_photoluminescence.txt
# opening file 4 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#38_photoluminescence.txt
# loaded  file 4 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#38_photoluminescence.txt
# opening file 5 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#39_photoluminescence.txt
# loaded  file 5 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#39_photoluminescence.txt
# opening file 6 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#40_photoluminescence.txt
# loaded  file 6 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#40_photoluminescence.txt
# opening file 7 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#41_photoluminescence.txt
# loaded  file 7 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#41_photoluminescence.txt
# opening file 8 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#42_photoluminescence.txt
# loaded  file 8 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#42_photoluminescence.txt
# opening file 9 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#43_photoluminescence.txt
# loaded  file 9 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#43_photoluminescence.txt
# opening file 10 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#44_photoluminescence.txt
# loaded  file 10 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#44_photoluminescence.txt
# opening file 11 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#45_photoluminescence.txt
# loaded  file 11 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#45_photoluminescence.txt
# opening file 12 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#46_photoluminescence.txt
# loaded  file 12 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#46_photoluminescence.txt
# opening file 13 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#47_photoluminescence.txt
# loaded  file 13 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#47_photoluminescence.txt
# opening file 14 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#48_photoluminescence.txt
# loaded  file 14 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#48_photoluminescence.txt
# opening file 15 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#49_photoluminescence.txt
# loaded  file 15 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#49_photoluminescence.txt
# opening file 16 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#50_photoluminescence.txt
# loaded  file 16 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#50_photoluminescence.txt
# opening file 17 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#51_photoluminescence.txt
# loaded  file 17 of 51: ../../data/Raman_Mouse/real_photo_NN/Kidney_map_150z25_60s_#51_photoluminescence.txt
# opening file 18 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150x25_60s_#10_photoluminescence.txt
# loaded  file 18 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150x25_60s_#10_photoluminescence.txt
# opening file 19 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150x25_60s_#13_photoluminescence.txt
# loaded  file 19 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150x25_60s_#13_photoluminescence.txt
# opening file 20 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150x25_60s_#7_photoluminescence.txt
# loaded  file 20 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150x25_60s_#7_photoluminescence.txt
# opening file 21 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150x25_60s_#9_photoluminescence.txt
# loaded  file 21 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150x25_60s_#9_photoluminescence.txt
# opening file 22 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#01_photoluminescence.txt
# loaded  file 22 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#01_photoluminescence.txt
# opening file 23 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#03_photoluminescence.txt
# loaded  file 23 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#03_photoluminescence.txt
# opening file 24 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#05_photoluminescence.txt
# loaded  file 24 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#05_photoluminescence.txt
# opening file 25 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#11_photoluminescence.txt
# loaded  file 25 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#11_photoluminescence.txt
# opening file 26 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#12_photoluminescence.txt
# loaded  file 26 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#12_photoluminescence.txt
# opening file 27 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#14_photoluminescence.txt
# loaded  file 27 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#14_photoluminescence.txt
# opening file 28 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#15_photoluminescence.txt
# loaded  file 28 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#15_photoluminescence.txt
# opening file 29 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#16_photoluminescence.txt
# loaded  file 29 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#16_photoluminescence.txt
# opening file 30 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#17_photoluminescence.txt
# loaded  file 30 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#17_photoluminescence.txt
# opening file 31 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#2_photoluminescence.txt
# loaded  file 31 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#2_photoluminescence.txt
# opening file 32 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#4_photoluminescence.txt
# loaded  file 32 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#4_photoluminescence.txt
# opening file 33 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#6_photoluminescence.txt
# loaded  file 33 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#6_photoluminescence.txt
# opening file 34 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#8_photoluminescence.txt
# loaded  file 34 of 51: ../../data/Raman_Mouse/real_photo_NN/Liver_map_150z25_60s_#8_photoluminescence.txt
# opening file 35 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#18_photoluminescence.txt
# loaded  file 35 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#18_photoluminescence.txt
# opening file 36 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#19_photoluminescence.txt
# loaded  file 36 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#19_photoluminescence.txt
# opening file 37 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#20_photoluminescence.txt
# loaded  file 37 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#20_photoluminescence.txt
# opening file 38 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#21_photoluminescence.txt
# loaded  file 38 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#21_photoluminescence.txt
# opening file 39 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#22_photoluminescence.txt
# loaded  file 39 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#22_photoluminescence.txt
# opening file 40 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#23_photoluminescence.txt
# loaded  file 40 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#23_photoluminescence.txt
# opening file 41 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#24_photoluminescence.txt
# loaded  file 41 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#24_photoluminescence.txt
# opening file 42 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#25_photoluminescence.txt
# loaded  file 42 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#25_photoluminescence.txt
# opening file 43 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#26_photoluminescence.txt
# loaded  file 43 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#26_photoluminescence.txt
# opening file 44 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#27_photoluminescence.txt
# loaded  file 44 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#27_photoluminescence.txt
# opening file 45 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#28_photoluminescence.txt
# loaded  file 45 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#28_photoluminescence.txt
# opening file 46 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#29_photoluminescence.txt
# loaded  file 46 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#29_photoluminescence.txt
# opening file 47 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#30_photoluminescence.txt
# loaded  file 47 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#30_photoluminescence.txt
# opening file 48 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#31_photoluminescence.txt
# loaded  file 48 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#31_photoluminescence.txt
# opening file 49 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#32_photoluminescence.txt
# loaded  file 49 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#32_photoluminescence.txt
# opening file 50 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#33_photoluminescence.txt
# loaded  file 50 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#33_photoluminescence.txt
# opening file 51 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#34_photoluminescence.txt
# loaded  file 51 of 51: ../../data/Raman_Mouse/real_photo_NN/Muscle_map_150z25_60s_#34_photoluminescence.txt

# %%
# x = data[1][0]
# raw_lst = []
# for i in range(len(filenames)):
#     raw_lst += [data[0][i].reshape(-1,data[0][0].shape[-1])]

photo_our_lst = []
for i in range(len(filenames)):
    photo_our_lst += [photo_Our[0][i].reshape(-1,photo_Our[0][0].shape[-1])]

photo_NN_lst = []
for i in range(len(filenames)):
    photo_NN_lst += [photo_NN[0][i].reshape(-1,photo_NN[0][0].shape[-1])]

# %%
shape = photo_NN_lst[0].shape[0] * 51
data = np.concatenate(photo_NN_lst[:1] + photo_our_lst[:1])
# target = np.concatenate((np.ones(shape), np.zeros(shape)))

data2 = np.concatenate(photo_NN_lst[:] + photo_our_lst[:])
target = np.concatenate((np.ones(shape), np.zeros(shape)))

# %%
pca = PCA(n_components=20)
pca.fit(data)
x = pca.transform(data2)
y = pca.components_

# %%
plt.rcParams['figure.figsize'] = (10.0, 6.0)
plt.rcParams['figure.dpi'] = 100
plt.rcParams['lines.linewidth'] = 1

for dim in range(0,20,2):
    
    plt.scatter(x[:, 0+dim], x[:, 1+dim], c=target, s=1)
#     plt.xlim(-30000,50000)
#     plt.ylim(-20000,20000)
    plt.show()
    plt.plot(y[0+dim])
    plt.plot(y[1+dim])
    plt.show()

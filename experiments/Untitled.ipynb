# %%
from load_modules import *

# %%
x = np.linspace(-3,3,100)
y = np.exp(x)

X = np.stack((np.ones(len(x)), x)).T
X = np.exp(X)

# b = np.linalg.inv(X.T @ X) @ X.T @ np.log(y)
b = np.linalg.inv(X.T @ X) @ X.T @ y
# X, b

# %%
plt.plot(x,y)
plt.plot(x,X@b)
# plt.plot(x, np.exp(X@b))
# plt.plot(x,np.log(y))

# %%
gaus2 = lambda x,sigma: np.exp(np.e)**(-0.5 * (x/sigma)**2)
gaus = lambda x,sigma: np.exp(-0.5 * (x/sigma)**2)

plt.plot(np.exp(gaus(x, 0.5)))
plt.plot(gaus2(x, 0.5))

# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
import random
import glob
import os

plt.rcParams['figure.figsize'] = (15.0, 10.0)

# %%
file_location = "../data/Raman_Mouse/raman_2022-12-01 12-13-34.452351/"
file_location2 = "../data/Raman_Mouse/preprocess_Vassilis/"

filenames = sorted(glob.glob(file_location+'/[!Wave|File]*.npy'))
filenames2 = sorted(glob.glob(file_location2+'/[!Wave|File]*.npy'))
data = []
data2 = []
for f in filenames:
    data.append(np.load(f))
    data2.append(np.load(f"{file_location2}{os.path.splitext(os.path.basename(f))[0]}_f_Reni.npy"))
# for f in filenames2:
#     data2.append(np.load(f))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-90fe6aed6b59> in <module>
#       8 for f in filenames:
#       9     data.append(np.load(f))
# ---> 10     data2.append(np.load(f"{file_location2}{os.path.basename(f)}_f_Reni.npy"))
#      11 # for f in filenames2:
#      12 #     data2.append(np.load(f))
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/Raman_Mouse/preprocess_Vassilis/Kidney_map_150z25_60s_#35_raman.npy_f_Reni.npy'

# %%
os.path.basename(f)
# Out:
# 'Y_coordinates.npy'

# %%
# assume linear increase in wavelength 
wavelength = np.load(f"{file_location}Wavenumbers.npy")
wavelength2 = np.load(f"{os.path.splitext(filenames2[0])[0]}_wavelength.npy")
shape = data[0].shape

# raman_data = []
# photo_data = []
# for x in data:
#     tmp = copy.copy(x.reshape(-1, x.shape[-1]))
# #     tmp1 = GSP.smoothing(tmp, smooth=5, transition=10, spike_width=15)
#     tmp1, tmp2 = GSP.split_Raman_af(GSP.smoothing(tmp, smooth=5, transition=10, spike_width=15), wavelength, 7)
#     raman_data.append(tmp1)
#     photo_data.append(tmp2)

# %%
# #Smoothing
# x=random.randint(0,24)
# y=random.randint(0,149)
# print(x,y)

# plt.plot(wavelength, raman_data[0][x+y*25])
# plt.plot(wavelength, data[0][y,x], alpha=0.3)
# plt.show()

# %%
x=random.randint(0,24)
y=random.randint(0,149)
i=random.randint(0,50)
print(i,x,y)

plt.plot(wavelength, data[i][y,x], label='new')
print(data2[0].shape)
plt.plot(wavelength2[:674], data2[i][y,x][:674], alpha=0.5, label='old')
plt.legend()
plt.show()
# Out:
# 2 6 27
# (150, 25, 674)

# %%
# #splitting
# x=random.randint(0,24)
# y=random.randint(0,149)
# print(x,y)

# plt.plot(wavelength, raman_data[0][x+y*25])
# plt.plot(wavelength, photo_data[0][x+y*25])
# plt.plot(wavelength, data[0][y,x])
# plt.plot(wavelength, data[0][y,x]-photo_data[0][x+y*25]-raman_data[0][x+y*25])
# plt.show()

# %%
# for i in range(0,25*150, 37):
#     plt.plot(wavelength, raman_data[0][i])
